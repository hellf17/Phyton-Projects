# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# load the csv file into a pandas DataFrame
df = pd.read_csv('diseases.csv')

# group the DataFrame by the disease column and concatenate the symptom columns
df_grouped = df.groupby('Disease').agg(lambda x: ','.join(set(x.dropna())))

# reset the index to make the disease column a regular column
df_grouped = df_grouped.reset_index()

# Loop through each row
for index, row in df_grouped.iterrows():
    # Create an empty list to store unique symptoms for the current disease
    unique_symptoms = []
    
    # Loop through each symptom column for the current disease
    for col in df_grouped.columns[1:]:
        # Check if the symptom column has multiple symptoms separated by a comma
        if ',' in row[col]:
            # Split the symptoms by comma and add them to the unique symptoms list
            for symptom in row[col].split(', '):
                if symptom not in unique_symptoms:
                    unique_symptoms.append(symptom)
        else:
            # If the symptom column has only one symptom, add it to the unique symptoms list
            if row[col] not in unique_symptoms:
                unique_symptoms.append(row[col])
    
    # Update the symptom columns for the current disease with the unique symptoms
    df_grouped.loc[index, df_grouped.columns[1:]] = ','.join(unique_symptoms)

# Drop others columns
df_grouped = df_grouped.iloc[:, :2]

# Rename Disease to disease and Symptom_1 to symptoms
df_grouped = df_grouped.rename(columns={'Disease': 'disease'})
df_grouped = df_grouped.rename(columns={'Symptom_1': 'symptoms'})

#Clean blankspaces in symptoms
df_grouped['symptoms'] = df_grouped['symptoms'].str.split(',').apply(lambda x: [s.strip() for s in x]).str.join(',')

# Instantiate the CountVectorizer
count_vectorizer = CountVectorizer(tokenizer=lambda x: x.split(', '))

# Fit and transform the symptoms column
symptoms_encoded = count_vectorizer.fit_transform(df_grouped['symptoms'])

# Create a new DataFrame with the encoded symptoms
symptoms_df = pd.DataFrame(symptoms_encoded.toarray(), columns=count_vectorizer.get_feature_names_out())

# Concatenate the new symptoms DataFrame with the original DataFrame
df_encoded = pd.concat([df_grouped.drop(columns=['symptoms']), symptoms_df], axis=1)

print(df_encoded.dtypes)
# Out:
# disease                                                                                                                                                                                                                                                                                 object
# back_pain,weakness_in_limbs,neck_pain,dizziness,dizziness,loss_of_balance,loss_of_balance,                                                                                                                                                                                               int64
# bladder_discomfort,burning_micturition,foul_smell_of urine,continuous_feel_of_urine,                                                                                                                                                                                                     int64
# breathlessness,vomiting,sweating,chest_pain,                                                                                                                                                                                                                                             int64
# chest_pain,headache,dizziness,dizziness,loss_of_balance,loss_of_balance,lack_of_concentration,lack_of_concentration,                                                                                                                                                                     int64
# chills,fatigue,vomiting,high_fever,headache,nausea,headache,constipation,abdominal_pain,diarrhoea,toxic_look_(typhos),belly_pain,belly_pain,                                                                                                                                             int64
# chills,vomiting,fatigue,weight_loss,weight_loss,cough,cough,high_fever,breathlessness,sweating,loss_of_appetite,mild_fever,mild_fever,yellowing_of_eyes,yellowing_of_eyes,swelled_lymph_nodes,malaise,phlegm,chest_pain,blood_in_sputum,blood_in_sputum,                                 int64
# chills,vomiting,vomiting,high_fever,sweating,headache,nausea,diarrhoea,muscle_pain,                                                                                                                                                                                                      int64
# constipation,pain_during_bowel_movements,pain_in_anal_region,bloody_stool,pain_in_anal_region,irritation_in_anus,irritation_in_anus,                                                                                                                                                     int64
# continuous_sneezing,chills,fatigue,cough,cough,high_fever,headache,swelled_lymph_nodes,headache,malaise,swelled_lymph_nodes,phlegm,phlegm,throat_irritation,redness_of_eyes,sinus_pressure,redness_of_eyes,runny_nose,runny_nose,congestion,chest_pain,loss_of_smell,muscle_pain         int64
# continuous_sneezing,shivering,chills,watering_from_eyes,watering_from_eyes,                                                                                                                                                                                                              int64
# fatigue,chills,cough,cough,high_fever,breathlessness,sweating,malaise,phlegm,chest_pain,fast_heart_rate,rusty_sputum,                                                                                                                                                                    int64
# fatigue,cough,cough,high_fever,breathlessness,family_history,breathlessness,mucoid_sputum,mucoid_sputum,                                                                                                                                                                                 int64
# fatigue,cramps,cramps,bruising,obesity,swollen_legs,swollen_blood_vessels,prominent_veins_on_calf,prominent_veins_on_calf,                                                                                                                                                               int64
# fatigue,itching,fatigue,lethargy,yellowish_skin,dark_urine,loss_of_appetite,abdominal_pain,abdominal_pain,yellow_urine,yellow_urine,yellowing_of_eyes,malaise,receiving_blood_transfusion,receiving_blood_transfusion,receiving_unsterile_injections,receiving_unsterile_injections,     int64
# fatigue,vomiting,anxiety,sweating,headache,nausea,blurred_and_distorted_vision,nausea,excessive_hunger,drying_and_tingling_lips,slurred_speech,irritability,palpitations,palpitations,                                                                                                   int64
# fatigue,weight_gain,weight_gain,cold_hands_and_feets,mood_swings,lethargy,lethargy,dizziness,dizziness,puffy_face_and_eyes,enlarged_thyroid,brittle_nails,swollen_extremeties,depression,swollen_extremeties,irritability,irritability,abnormal_menstruation,abnormal_menstruation,      int64
# fatigue,weight_loss,restlessness,lethargy,restlessness,irregular_sugar_level,blurred_and_distorted_vision,obesity,obesity,excessive_hunger,excessive_hunger,increased_appetite,increased_appetite,polyuria,polyuria,                                                                     int64
# indigestion,acidity,headache,blurred_and_distorted_vision,excessive_hunger,stiff_neck,depression,depression,irritability,irritability,visual_disturbances,visual_disturbances,                                                                                                           int64
# indigestion,vomiting,loss_of_appetite,indigestion,abdominal_pain,loss_of_appetite,passage_of_gases,passage_of_gases,internal_itching,internal_itching,                                                                                                                                   int64
# joint_pain,vomiting,fatigue,high_fever,yellowish_skin,dark_urine,nausea,loss_of_appetite,nausea,abdominal_pain,abdominal_pain,yellowing_of_eyes,acute_liver_failure,coma,stomach_bleeding,                                                                                               int64
# joint_pain,vomiting,fatigue,yellowish_skin,fatigue,dark_urine,nausea,loss_of_appetite,nausea,abdominal_pain,abdominal_pain,yellowing_of_eyes,yellowing_of_eyes,                                                                                                                          int64
# joint_pain,vomiting,yellowish_skin,dark_urine,nausea,loss_of_appetite,nausea,abdominal_pain,abdominal_pain,diarrhoea,mild_fever,yellowing_of_eyes,muscle_pain,                                                                                                                           int64
# mood_swings,fatigue,weight_loss,restlessness,sweating,diarrhoea,fast_heart_rate,excessive_hunger,muscle_weakness,irritability,abnormal_menstruation,abnormal_menstruation,                                                                                                               int64
# neck_pain,joint_pain,knee_pain,neck_pain,hip_joint_pain,hip_joint_pain,swelling_joints,swelling_joints,painful_walking,painful_walking,                                                                                                                                                  int64
# patches_in_throat,muscle_wasting,high_fever,extra_marital_contacts,                                                                                                                                                                                                                      int64
# skin_rash,chills,chills,joint_pain,joint_pain,vomiting,fatigue,high_fever,headache,nausea,headache,loss_of_appetite,nausea,pain_behind_the_eyes,back_pain,malaise,muscle_pain,red_spots_over_body,red_spots_over_body,                                                                   int64
# skin_rash,high_fever,blister,red_sore_around_nose,red_sore_around_nose,yellow_crust_ooze,yellow_crust_ooze,                                                                                                                                                                              int64
# skin_rash,itching,skin_rash,fatigue,fatigue,lethargy,lethargy,high_fever,headache,loss_of_appetite,headache,mild_fever,mild_fever,swelled_lymph_nodes,malaise,red_spots_over_body,red_spots_over_body,                                                                                   int64
# skin_rash,itching,skin_rash,nodal_skin_eruptions,nodal_skin_eruptions,dischromic _patches,dischromic _patches,                                                                                                                                                                           int64
# skin_rash,itching,skin_rash,stomach_pain,stomach_pain,burning_micturition,burning_micturition,spotting_ urination,spotting_ urination,                                                                                                                                                   int64
# skin_rash,joint_pain,joint_pain,skin_peeling,skin_peeling,silver_like_dusting,small_dents_in_nails,inflammatory_nails,inflammatory_nails,                                                                                                                                                int64
# skin_rash,pus_filled_pimples,blackheads,scurring,blackheads,                                                                                                                                                                                                                             int64
# stiff_neck,muscle_weakness,swelling_joints,swelling_joints,movement_stiffness,painful_walking,                                                                                                                                                                                           int64
# stomach_pain,acidity,ulcers_on_tongue,vomiting,vomiting,cough,chest_pain,                                                                                                                                                                                                                int64
# vomiting,headache,nausea,spinning_movements,loss_of_balance,unsteadiness,unsteadiness,                                                                                                                                                                                                   int64
# vomiting,headache,weakness_of_one_body_side,altered_sensorium,altered_sensorium,                                                                                                                                                                                                         int64
# vomiting,itching,fatigue,vomiting,weight_loss,weight_loss,high_fever,yellowish_skin,dark_urine,abdominal_pain,                                                                                                                                                                           int64
# vomiting,itching,yellowish_skin,vomiting,nausea,loss_of_appetite,abdominal_pain,abdominal_pain,yellowing_of_eyes,yellowing_of_eyes,                                                                                                                                                      int64
# vomiting,sunken_eyes,dehydration,diarrhoea,dehydration,                                                                                                                                                                                                                                  int64
# yellowish_skin,fatigue,nausea,loss_of_appetite,yellowing_of_eyes,family_history,                                                                                                                                                                                                         int64
# yellowish_skin,vomiting,abdominal_pain,abdominal_pain,swelling_of_stomach,distention_of_abdomen,history_of_alcohol_consumption,distention_of_abdomen,fluid_overload,fluid_overload,                                                                                                      int64
# dtype: object

# %%
X = df_encoded.iloc[:, 1:]
y = df_encoded.iloc[:, 0]

# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.29)

# Define the model
model = Sequential()
model.add(Dense(32, activation='relu', input_dim=X_train.shape[1]))
model.add(Dense(16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# Fit the model on the training data
history = model.fit(X_train, y_train, epochs=100, batch_size=32, validation_data=(X_test, y_test))

# Evaluate the model on the testing data
test_loss, test_acc = model.evaluate(X_test, y_test)
print('Test accuracy:', test_acc)

# Make predictions on new cases
new_cases = np.array([[1, 0, 0, 1, 0], [0, 0, 1, 1, 1]])
new_cases = pd.get_dummies(pd.DataFrame(new_cases, columns=symptoms_encoded.columns))
probabilities = model.predict(new_cases)
print('Probabilities:', probabilities)
